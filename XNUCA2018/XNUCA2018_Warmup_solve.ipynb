# %%
# Dave和Alice的N相同，运用共模攻击。
# 共模攻击原理：
# pow(m , e1 , n) = c1
# pow(m , e2 , n) = c2
# 找到x , y使得pow(m , e1 * x + e2 * y, n) == pow(m , 1 , n)

# %%
N = ...
e_Dave = 6947
c_Dave = ...
e_Alice = 7669
c_Alice = ...
e1 = e_Dave
c1 = c_Dave
e2 = e_Alice
c2 = c_Alice
n=N
import gmpy2
from libnum import n2s
s0, s1, s2 = gmpy2.gcdext(e1, e2)
if s1 < 0:
    s1 = -s1
    c1 = gmpy2.invert(c1, n)
elif s2 < 0:
    s2 = -s2
    c2 = gmpy2.invert(c2, n)
m = gmpy2.powmod(c1, s1, n)*gmpy2.powmod(c2, s2, n) % n
print((m))
# 112964323472000743478440348317734406992674862238452530671873661
print(n2s(112964323472000743478440348317734406992674862238452530671873661))
# Out:
# 112964323472000743478440348317734406992674862238452530671873661
